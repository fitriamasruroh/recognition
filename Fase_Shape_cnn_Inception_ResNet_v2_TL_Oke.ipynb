#   inflating: Face_shape_5/Heart/heart (139).jpg
#   inflating: Face_shape_5/Heart/heart (140).jpg
#   inflating: Face_shape_5/Heart/heart (141).jpg
#   inflating: Face_shape_5/Heart/heart (156).jpg
#   inflating: Face_shape_5/Heart/heart (161).jpg
#   inflating: Face_shape_5/Heart/heart (163).jpg
#   inflating: Face_shape_5/Heart/heart (189).jpg
#   inflating: Face_shape_5/Heart/heart (192).jpg
#   inflating: Face_shape_5/Heart/heart (194).jpg
#   inflating: Face_shape_5/Heart/heart (196).jpg
#   inflating: Face_shape_5/Heart/heart (197).jpg
#   inflating: Face_shape_5/Heart/heart (200).jpg
#   inflating: Face_shape_5/Heart/heart (203).jpg
#   inflating: Face_shape_5/Heart/heart (204).jpg
#   inflating: Face_shape_5/Heart/heart (223).jpg
#   inflating: Face_shape_5/Heart/heart (224).jpg
#   inflating: Face_shape_5/Heart/heart (225).jpg
#   inflating: Face_shape_5/Heart/heart (226).jpg
#   inflating: Face_shape_5/Heart/heart (227).jpg
#   inflating: Face_shape_5/Heart/heart (228).jpg
#   inflating: Face_shape_5/Heart/heart (229).jpg
#   inflating: Face_shape_5/Heart/heart (230).jpg
#   inflating: Face_shape_5/Heart/heart (233).jpg
#   inflating: Face_shape_5/Heart/heart (234).jpg
#   inflating: Face_shape_5/Heart/heart (235).jpg
#   inflating: Face_shape_5/Heart/heart (236).jpg
#   inflating: Face_shape_5/Heart/heart (237).jpg
#   inflating: Face_shape_5/Heart/heart (238).jpg
#   inflating: Face_shape_5/Heart/heart (239).jpg
#   inflating: Face_shape_5/Heart/heart (240).jpg
#   inflating: Face_shape_5/Heart/heart (247).jpg
#   inflating: Face_shape_5/Heart/heart (248).jpg
#   inflating: Face_shape_5/Heart/heart (249).jpg
#   inflating: Face_shape_5/Heart/heart (250).jpg
#   inflating: Face_shape_5/Heart/heart (251).jpg
#   inflating: Face_shape_5/Heart/heart (252).jpg
#   inflating: Face_shape_5/Heart/heart (253).jpg
#   inflating: Face_shape_5/Heart/heart (254).jpg
#   inflating: Face_shape_5/Heart/heart (255).jpg
#   inflating: Face_shape_5/Heart/heart (256).jpg
#   inflating: Face_shape_5/Heart/heart (257).jpg
#   inflating: Face_shape_5/Heart/heart (258).jpg
#   inflating: Face_shape_5/Heart/heart (259).jpg
#   inflating: Face_shape_5/Heart/heart (260).jpg
#   inflating: Face_shape_5/Heart/heart (261).jpg
#   inflating: Face_shape_5/Heart/heart (262).jpg
#   inflating: Face_shape_5/Heart/heart (263).jpg
#   inflating: Face_shape_5/Heart/heart (264).jpg
#   inflating: Face_shape_5/Heart/heart (265).jpg
#   inflating: Face_shape_5/Heart/heart (266).jpg
#   inflating: Face_shape_5/Heart/heart (267).jpg
#   inflating: Face_shape_5/Heart/heart (268).jpg
#   inflating: Face_shape_5/Heart/heart (269).jpg
#   inflating: Face_shape_5/Heart/heart (270).jpg
#   inflating: Face_shape_5/Heart/heart (271).jpg
#   inflating: Face_shape_5/Heart/heart (272).jpg
#   inflating: Face_shape_5/Heart/heart (273).jpg
#   inflating: Face_shape_5/Heart/heart (274).jpg
#   inflating: Face_shape_5/Heart/heart (275).jpg
#   inflating: Face_shape_5/Heart/heart (276).jpg
#   inflating: Face_shape_5/Heart/heart (277).jpg
#   inflating: Face_shape_5/Heart/heart (278).jpg
#   inflating: Face_shape_5/Heart/heart (279).jpg
#   inflating: Face_shape_5/Heart/heart (280).jpg
#   inflating: Face_shape_5/Heart/heart (281).jpg
#   inflating: Face_shape_5/Heart/heart (282).jpg
#   inflating: Face_shape_5/Heart/heart (283).jpg
#   inflating: Face_shape_5/Heart/heart (284).jpg
#   inflating: Face_shape_5/Heart/heart (285).jpg
#   inflating: Face_shape_5/Heart/heart (286).jpg
#   inflating: Face_shape_5/Heart/heart (287).jpg
#   inflating: Face_shape_5/Heart/heart (288).jpg
#   inflating: Face_shape_5/Heart/heart (289).jpg
#   inflating: Face_shape_5/Heart/heart (290).jpg
#   inflating: Face_shape_5/Heart/heart (291).jpg
#   inflating: Face_shape_5/Heart/heart (292).jpg
#   inflating: Face_shape_5/Heart/heart (293).jpg
#   inflating: Face_shape_5/Heart/heart (294).jpg
#   inflating: Face_shape_5/Heart/heart (295).jpg
#   inflating: Face_shape_5/Heart/heart (296).jpg
#   inflating: Face_shape_5/Heart/heart (297).jpg
#   inflating: Face_shape_5/Heart/heart (298).jpg
#   inflating: Face_shape_5/Heart/heart (299).jpg
#   inflating: Face_shape_5/Heart/heart (3).jpg
#   inflating: Face_shape_5/Heart/heart (300).jpg
#   inflating: Face_shape_5/Heart/heart (301).jpg
#   inflating: Face_shape_5/Heart/heart (302).jpg
#   inflating: Face_shape_5/Heart/heart (303).jpg
#   inflating: Face_shape_5/Heart/heart (304).jpg
#   inflating: Face_shape_5/Heart/heart (305).jpg
#   inflating: Face_shape_5/Heart/heart (306).jpg
#   inflating: Face_shape_5/Heart/heart (307).jpg
#   inflating: Face_shape_5/Heart/heart (308).jpg
#   inflating: Face_shape_5/Heart/heart (309).jpg
#   inflating: Face_shape_5/Heart/heart (310).jpg
#   inflating: Face_shape_5/Heart/heart (311).jpg
#   inflating: Face_shape_5/Heart/heart (312).jpg
#   inflating: Face_shape_5/Heart/heart (313).jpg
#   inflating: Face_shape_5/Heart/heart (314).jpg
#   inflating: Face_shape_5/Heart/heart (315).jpg
#   inflating: Face_shape_5/Heart/heart (316).jpg
#   inflating: Face_shape_5/Heart/heart (317).jpg
#   inflating: Face_shape_5/Heart/heart (318).jpg
#   inflating: Face_shape_5/Heart/heart (319).jpg
#   inflating: Face_shape_5/Heart/heart (320).jpg
#   inflating: Face_shape_5/Heart/heart (321).jpg
#   inflating: Face_shape_5/Heart/heart (322).jpg
#   inflating: Face_shape_5/Heart/heart (323).jpg
#   inflating: Face_shape_5/Heart/heart (324).jpg
#   inflating: Face_shape_5/Heart/heart (325).jpg
#   inflating: Face_shape_5/Heart/heart (326).jpg
#   inflating: Face_shape_5/Heart/heart (327).jpg
#   inflating: Face_shape_5/Heart/heart (328).jpg
#   inflating: Face_shape_5/Heart/heart (329).jpg
#   inflating: Face_shape_5/Heart/heart (330).jpg
#   inflating: Face_shape_5/Heart/heart (331).jpg
#   inflating: Face_shape_5/Heart/heart (332).jpg
#   inflating: Face_shape_5/Heart/heart (333).jpg
#   inflating: Face_shape_5/Heart/heart (334).jpg
#   inflating: Face_shape_5/Heart/heart (335).jpg
#   inflating: Face_shape_5/Heart/heart (336).jpg
#   inflating: Face_shape_5/Heart/heart (337).jpg
#   inflating: Face_shape_5/Heart/heart (338).jpg
#   inflating: Face_shape_5/Heart/heart (339).jpg
#   inflating: Face_shape_5/Heart/heart (340).jpg
#   inflating: Face_shape_5/Heart/heart (341).jpg
#   inflating: Face_shape_5/Heart/heart (342).jpg
#   inflating: Face_shape_5/Heart/heart (343).jpg
#   inflating: Face_shape_5/Heart/heart (344).jpg
#   inflating: Face_shape_5/Heart/heart (345).jpg
#   inflating: Face_shape_5/Heart/heart (346).jpg
#   inflating: Face_shape_5/Heart/heart (347).jpg
#   inflating: Face_shape_5/Heart/heart (348).jpg
#   inflating: Face_shape_5/Heart/heart (349).jpg
#   inflating: Face_shape_5/Heart/heart (350).jpg
#   inflating: Face_shape_5/Heart/heart (351).jpg
#   inflating: Face_shape_5/Heart/heart (352).jpg
#   inflating: Face_shape_5/Heart/heart (353).jpg
#   inflating: Face_shape_5/Heart/heart (354).jpg
#   inflating: Face_shape_5/Heart/heart (355).jpg
#   inflating: Face_shape_5/Heart/heart (356).jpg
#   inflating: Face_shape_5/Heart/heart (357).jpg
#   inflating: Face_shape_5/Heart/heart (358).jpg
#   inflating: Face_shape_5/Heart/heart (359).jpg
#   inflating: Face_shape_5/Heart/heart (360).jpg
#   inflating: Face_shape_5/Heart/heart (361).jpg
#   inflating: Face_shape_5/Heart/heart (362).jpg
#   inflating: Face_shape_5/Heart/heart (363).jpg
#   inflating: Face_shape_5/Heart/heart (364).jpg
#   inflating: Face_shape_5/Heart/heart (365).jpg
#   inflating: Face_shape_5/Heart/heart (366).jpg
#   inflating: Face_shape_5/Heart/heart (367).jpg
#   inflating: Face_shape_5/Heart/heart (368).jpg
#   inflating: Face_shape_5/Heart/heart (369).jpg
#   inflating: Face_shape_5/Heart/heart (37).jpg
#   inflating: Face_shape_5/Heart/heart (370).jpg
#   inflating: Face_shape_5/Heart/heart (371).jpg
#   inflating: Face_shape_5/Heart/heart (372).jpg
#   inflating: Face_shape_5/Heart/heart (373).jpg
#   inflating: Face_shape_5/Heart/heart (374).jpg
#   inflating: Face_shape_5/Heart/heart (375).jpg
#   inflating: Face_shape_5/Heart/heart (376).jpg
#   inflating: Face_shape_5/Heart/heart (377).jpg
#   inflating: Face_shape_5/Heart/heart (378).jpg
#   inflating: Face_shape_5/Heart/heart (379).jpg
#   inflating: Face_shape_5/Heart/heart (380).jpg
#   inflating: Face_shape_5/Heart/heart (381).jpg
#   inflating: Face_shape_5/Heart/heart (382).jpg
#   inflating: Face_shape_5/Heart/heart (383).jpg
#   inflating: Face_shape_5/Heart/heart (384).jpg
#   inflating: Face_shape_5/Heart/heart (385).jpg
#   inflating: Face_shape_5/Heart/heart (386).jpg
#   inflating: Face_shape_5/Heart/heart (387).jpg
#   inflating: Face_shape_5/Heart/heart (562).jpg
#   inflating: Face_shape_5/Heart/heart (563).jpg
#   inflating: Face_shape_5/Heart/heart (564).jpg
#   inflating: Face_shape_5/Heart/heart (565).jpg
#   inflating: Face_shape_5/Heart/heart (566).jpg
#   inflating: Face_shape_5/Heart/heart (567).jpg
#   inflating: Face_shape_5/Heart/heart (568).jpg
#   inflating: Face_shape_5/Heart/heart (569).jpg
#   inflating: Face_shape_5/Heart/heart (570).jpg
#   inflating: Face_shape_5/Heart/heart (571).jpg
#   inflating: Face_shape_5/Heart/heart (572).jpg
#   inflating: Face_shape_5/Heart/heart (573).jpg
#   inflating: Face_shape_5/Heart/heart (574).jpg
#   inflating: Face_shape_5/Heart/heart (575).jpg
#   inflating: Face_shape_5/Heart/heart (576).jpg
#   inflating: Face_shape_5/Heart/heart (577).jpg
#   inflating: Face_shape_5/Heart/heart (578).jpg
#   inflating: Face_shape_5/Heart/heart (579).jpg
#   inflating: Face_shape_5/Heart/heart (580).jpg
#   inflating: Face_shape_5/Heart/heart (581).jpg
#   inflating: Face_shape_5/Heart/heart (582).jpg
#   inflating: Face_shape_5/Heart/heart (583).jpg
#   inflating: Face_shape_5/Heart/heart (584).jpg
#   inflating: Face_shape_5/Heart/heart (585).jpg
#   inflating: Face_shape_5/Heart/heart (586).jpg
#   inflating: Face_shape_5/Heart/heart (587).jpg
#   inflating: Face_shape_5/Heart/heart (588).jpg
#   inflating: Face_shape_5/Heart/heart (589).jpg
#   inflating: Face_shape_5/Heart/heart (590).jpg
#   inflating: Face_shape_5/Heart/heart (591).jpg
#   inflating: Face_shape_5/Heart/heart (592).jpg
#   inflating: Face_shape_5/Heart/heart (593).jpg
#   inflating: Face_shape_5/Heart/heart (594).jpg
#   inflating: Face_shape_5/Heart/heart (595).jpg
#   inflating: Face_shape_5/Heart/heart (596).jpg
#   inflating: Face_shape_5/Heart/heart (597).jpg
#   inflating: Face_shape_5/Heart/heart (598).jpg
#   inflating: Face_shape_5/Heart/heart (599).jpg
#   inflating: Face_shape_5/Heart/heart (600).jpg
#   inflating: Face_shape_5/Heart/heart (601).jpg
#   inflating: Face_shape_5/Heart/heart (602).jpg
#   inflating: Face_shape_5/Heart/heart (603).jpg
#   inflating: Face_shape_5/Heart/heart (604).jpg
#   inflating: Face_shape_5/Heart/heart (605).jpg
#   inflating: Face_shape_5/Heart/heart (606).jpg
#   inflating: Face_shape_5/Heart/heart (607).jpg
#   inflating: Face_shape_5/Heart/heart (608).jpg
#   inflating: Face_shape_5/Heart/heart (609).jpg
#   inflating: Face_shape_5/Heart/heart (610).jpg
#   inflating: Face_shape_5/Heart/heart (611).jpg
#   inflating: Face_shape_5/Heart/heart (612).jpg
#   inflating: Face_shape_5/Heart/heart (613).jpg
#   inflating: Face_shape_5/Heart/heart (614).jpg
#   inflating: Face_shape_5/Heart/heart (615).jpg
#   inflating: Face_shape_5/Heart/heart (616).jpg
#   inflating: Face_shape_5/Heart/heart (617).jpg
#   inflating: Face_shape_5/Heart/heart (618).jpg
#   inflating: Face_shape_5/Heart/heart (619).jpg
#   inflating: Face_shape_5/Heart/heart (620).jpg
#   inflating: Face_shape_5/Heart/heart (621).jpg
#   inflating: Face_shape_5/Heart/heart (622).jpg
#   inflating: Face_shape_5/Heart/heart (623).jpg
#   inflating: Face_shape_5/Heart/heart (624).jpg
#   inflating: Face_shape_5/Heart/heart (625).jpg
#   inflating: Face_shape_5/Heart/heart (626).jpg
#   inflating: Face_shape_5/Heart/heart (627).jpg
#   inflating: Face_shape_5/Heart/heart (628).jpg
#   inflating: Face_shape_5/Heart/heart (629).jpg
#   inflating: Face_shape_5/Heart/heart (630).jpg
#   inflating: Face_shape_5/Heart/heart (631).jpg
#   inflating: Face_shape_5/Heart/heart (632).jpg
#   inflating: Face_shape_5/Heart/heart (633).jpg
#   inflating: Face_shape_5/Heart/heart (634).jpg
#   inflating: Face_shape_5/Heart/heart (635).jpg
#   inflating: Face_shape_5/Heart/heart (636).jpg
#   inflating: Face_shape_5/Heart/heart (637).jpg
#   inflating: Face_shape_5/Heart/heart (638).jpg
#   inflating: Face_shape_5/Heart/heart (639).jpg
#   inflating: Face_shape_5/Heart/heart (640).jpg
#   inflating: Face_shape_5/Heart/heart (641).jpg
#   inflating: Face_shape_5/Heart/heart (642).jpg
#   inflating: Face_shape_5/Heart/heart (643).jpg
#   inflating: Face_shape_5/Heart/heart (644).jpg
#   inflating: Face_shape_5/Heart/heart (645).jpg
#   inflating: Face_shape_5/Heart/heart (646).jpg
#   inflating: Face_shape_5/Heart/heart (647).jpg
#   inflating: Face_shape_5/Heart/heart (648).jpg
#   inflating: Face_shape_5/Heart/heart (649).jpg
#   inflating: Face_shape_5/Heart/heart (650).jpg
#   inflating: Face_shape_5/Heart/heart (651).jpg
#   inflating: Face_shape_5/Heart/heart (652).jpg
#   inflating: Face_shape_5/Heart/heart (653).jpg
#   inflating: Face_shape_5/Heart/heart (654).jpg
#   inflating: Face_shape_5/Heart/heart (655).jpg
#   inflating: Face_shape_5/Heart/heart (656).jpg
#   inflating: Face_shape_5/Heart/heart (657).jpg
#   inflating: Face_shape_5/Heart/heart (658).jpg
#   inflating: Face_shape_5/Heart/heart (659).jpg
#   inflating: Face_shape_5/Heart/heart (660).jpg
#   inflating: Face_shape_5/Heart/heart (661).jpg
#   inflating: Face_shape_5/Heart/heart (662).jpg
#   inflating: Face_shape_5/Heart/heart (663).jpg
#   inflating: Face_shape_5/Heart/heart (664).jpg
#   inflating: Face_shape_5/Heart/heart (665).jpg
#   inflating: Face_shape_5/Heart/heart (666).jpg
#   inflating: Face_shape_5/Heart/heart (667).jpg
#   inflating: Face_shape_5/Heart/heart (668).jpg
#   inflating: Face_shape_5/Heart/heart (669).jpg
#   inflating: Face_shape_5/Heart/heart (670).jpg
#   inflating: Face_shape_5/Heart/heart (671).jpg
#   inflating: Face_shape_5/Heart/heart (672).jpg
#   inflating: Face_shape_5/Heart/heart (673).jpg
#   inflating: Face_shape_5/Heart/heart (674).jpg
#   inflating: Face_shape_5/Heart/heart (675).jpg
#   inflating: Face_shape_5/Heart/heart (676).jpg
#   inflating: Face_shape_5/Heart/heart (677).jpg
#   inflating: Face_shape_5/Heart/heart (678).jpg
#   inflating: Face_shape_5/Heart/heart (679).jpg
#   inflating: Face_shape_5/Heart/heart (680).jpg
#   inflating: Face_shape_5/Heart/heart (681).jpg
#   inflating: Face_shape_5/Heart/heart (682).jpg
#   inflating: Face_shape_5/Heart/heart (683).jpg
#   inflating: Face_shape_5/Heart/heart (684).jpg
#   inflating: Face_shape_5/Heart/heart (685).jpg
#   inflating: Face_shape_5/Heart/heart (686).jpg
#   inflating: Face_shape_5/Heart/heart (687).jpg
#   inflating: Face_shape_5/Heart/heart (688).jpg
#   inflating: Face_shape_5/Heart/heart (689).jpg
#   inflating: Face_shape_5/Heart/heart (690).jpg
#   inflating: Face_shape_5/Heart/heart (691).jpg
#   inflating: Face_shape_5/Heart/heart (692).jpg
#   inflating: Face_shape_5/Heart/heart (693).jpg
#   inflating: Face_shape_5/Heart/heart (694).jpg
#   inflating: Face_shape_5/Heart/heart (695).jpg
#   inflating: Face_shape_5/Heart/heart (696).jpg
#   inflating: Face_shape_5/Heart/heart (697).jpg
#   inflating: Face_shape_5/Heart/heart (698).jpg
#   inflating: Face_shape_5/Heart/heart (699).jpg
#   inflating: Face_shape_5/Heart/heart (7).jpg
#   inflating: Face_shape_5/Heart/heart (700).jpg
#   inflating: Face_shape_5/Heart/heart (701).jpg
#   inflating: Face_shape_5/Heart/heart (702).jpg
#   inflating: Face_shape_5/Heart/heart (703).jpg
#   inflating: Face_shape_5/Heart/heart (704).jpg
#   inflating: Face_shape_5/Heart/heart (705).jpg
#   inflating: Face_shape_5/Heart/heart (706).jpg
#   inflating: Face_shape_5/Heart/heart (707).jpg
#   inflating: Face_shape_5/Heart/heart (708).jpg
#   inflating: Face_shape_5/Heart/heart (709).jpg
#   inflating: Face_shape_5/Heart/heart (710).jpg
#   inflating: Face_shape_5/Heart/heart (711).jpg
#   inflating: Face_shape_5/Heart/heart (712).jpg
#   inflating: Face_shape_5/Heart/heart (713).jpg
#   inflating: Face_shape_5/Heart/heart (714).jpg
#   inflating: Face_shape_5/Heart/heart (715).jpg
#   inflating: Face_shape_5/Heart/heart (716).jpg
#   inflating: Face_shape_5/Heart/heart (717).jpg
#   inflating: Face_shape_5/Heart/heart (718).jpg
#   inflating: Face_shape_5/Heart/heart (719).jpg
#   inflating: Face_shape_5/Heart/heart (720).jpg
#   inflating: Face_shape_5/Heart/heart (721).jpg
#   inflating: Face_shape_5/Heart/heart (722).jpg
#   inflating: Face_shape_5/Heart/heart (723).jpg
#   inflating: Face_shape_5/Heart/heart (724).jpg
#   inflating: Face_shape_5/Heart/heart (725).jpg
#   inflating: Face_shape_5/Heart/heart (726).jpg
#   inflating: Face_shape_5/Heart/heart (727).jpg
#   inflating: Face_shape_5/Heart/heart (728).jpg
#   inflating: Face_shape_5/Heart/heart (729).jpg
#   inflating: Face_shape_5/Heart/heart (730).jpg
#   inflating: Face_shape_5/Heart/heart (731).jpg
#   inflating: Face_shape_5/Heart/heart (732).jpg
#   inflating: Face_shape_5/Heart/heart (733).jpg
#   inflating: Face_shape_5/Heart/heart (734).jpg
#   inflating: Face_shape_5/Heart/heart (735).jpg
#   inflating: Face_shape_5/Heart/heart (736).jpg
#   inflating: Face_shape_5/Heart/heart (737).jpg
#   inflating: Face_shape_5/Heart/heart (738).jpg
#   inflating: Face_shape_5/Heart/heart (739).jpg
#   inflating: Face_shape_5/Heart/heart (740).jpg
#   inflating: Face_shape_5/Heart/heart (741).jpg
#   inflating: Face_shape_5/Heart/heart (742).jpg
#   inflating: Face_shape_5/Heart/heart (743).jpg
#   inflating: Face_shape_5/Heart/heart (744).jpg
#   inflating: Face_shape_5/Heart/heart (745).jpg
#   inflating: Face_shape_5/Heart/heart (746).jpg
#   inflating: Face_shape_5/Heart/heart (747).jpg
#   inflating: Face_shape_5/Heart/heart (748).jpg
#   inflating: Face_shape_5/Heart/heart (749).jpg
#   inflating: Face_shape_5/Heart/heart (750).jpg
#   inflating: Face_shape_5/Heart/heart (751).jpg
#   inflating: Face_shape_5/Heart/heart (752).jpg
#   inflating: Face_shape_5/Heart/heart (753).jpg
#   inflating: Face_shape_5/Heart/heart (754).jpg
#   inflating: Face_shape_5/Heart/heart (755).jpg
#   inflating: Face_shape_5/Heart/heart (756).jpg
#   inflating: Face_shape_5/Heart/heart (757).jpg
#   inflating: Face_shape_5/Heart/heart (758).jpg
#   inflating: Face_shape_5/Heart/heart (759).jpg
#   inflating: Face_shape_5/Heart/heart (760).jpg
#   inflating: Face_shape_5/Heart/heart (761).jpg
#   inflating: Face_shape_5/Heart/heart (762).jpg
#   inflating: Face_shape_5/Heart/heart (763).jpg
#   inflating: Face_shape_5/Heart/heart (764).jpg
#   inflating: Face_shape_5/Heart/heart (765).jpg
#   inflating: Face_shape_5/Heart/heart (766).jpg
#   inflating: Face_shape_5/Heart/heart (767).jpg
#   inflating: Face_shape_5/Heart/heart (768).jpg
#   inflating: Face_shape_5/Heart/heart (769).jpg
#   inflating: Face_shape_5/Heart/heart (770).jpg
#   inflating: Face_shape_5/Heart/heart (771).jpg
#   inflating: Face_shape_5/Heart/heart (772).jpg
#   inflating: Face_shape_5/Heart/heart (773).jpg
#   inflating: Face_shape_5/Heart/heart (774).jpg
#   inflating: Face_shape_5/Heart/heart (775).jpg
#   inflating: Face_shape_5/Heart/heart (776).jpg
#   inflating: Face_shape_5/Heart/heart (777).jpg
#   inflating: Face_shape_5/Heart/heart (778).jpg
#   inflating: Face_shape_5/Heart/heart (779).jpg
#   inflating: Face_shape_5/Heart/heart (780).jpg
#   inflating: Face_shape_5/Heart/heart (781).jpg
#   inflating: Face_shape_5/Heart/heart (782).jpg
#   inflating: Face_shape_5/Heart/heart (783).jpg
#   inflating: Face_shape_5/Heart/heart (784).jpg
#   inflating: Face_shape_5/Heart/heart (785).jpg
#   inflating: Face_shape_5/Heart/heart (786).jpg
#   inflating: Face_shape_5/Heart/heart (787).jpg
#   inflating: Face_shape_5/Heart/heart (788).jpg
#   inflating: Face_shape_5/Heart/heart (789).jpg
#   inflating: Face_shape_5/Heart/heart (790).jpg
#   inflating: Face_shape_5/Heart/heart (791).jpg
#   inflating: Face_shape_5/Heart/heart (857).jpg
#   inflating: Face_shape_5/Heart/heart (858).jpg
#   inflating: Face_shape_5/Heart/heart (859).jpg
#   inflating: Face_shape_5/Heart/heart (860).jpg
#   inflating: Face_shape_5/Heart/heart (861).jpg
#   inflating: Face_shape_5/Heart/heart (862).jpg
#   inflating: Face_shape_5/Heart/heart (863).jpg
#   inflating: Face_shape_5/Heart/heart (864).jpg
#   inflating: Face_shape_5/Heart/heart (865).jpg
#   inflating: Face_shape_5/Heart/heart (866).jpg
#   inflating: Face_shape_5/Heart/heart (867).jpg
#   inflating: Face_shape_5/Heart/heart (868).jpg
#   inflating: Face_shape_5/Heart/heart (869).jpg
#   inflating: Face_shape_5/Heart/heart (870).jpg
#   inflating: Face_shape_5/Heart/heart (871).jpg
#   inflating: Face_shape_5/Heart/heart (872).jpg
#   inflating: Face_shape_5/Heart/heart (873).jpg
#   inflating: Face_shape_5/Heart/heart (874).jpg
#   inflating: Face_shape_5/Heart/heart (875).jpg
#   inflating: Face_shape_5/Heart/heart (876).jpg
#   inflating: Face_shape_5/Heart/heart (877).jpg
#   inflating: Face_shape_5/Heart/heart (878).jpg
#   inflating: Face_shape_5/Heart/heart (879).jpg
#   inflating: Face_shape_5/Heart/heart (880).jpg
#   inflating: Face_shape_5/Heart/heart (881).jpg
#   inflating: Face_shape_5/Heart/heart (882).jpg
#   inflating: Face_shape_5/Heart/heart (883).jpg
#   inflating: Face_shape_5/Heart/heart (884).jpg
#   inflating: Face_shape_5/Heart/heart (885).jpg
#   inflating: Face_shape_5/Heart/heart (886).jpg
#   inflating: Face_shape_5/Heart/heart (887).jpg
#   inflating: Face_shape_5/Heart/heart (888).jpg
#   inflating: Face_shape_5/Heart/heart (889).jpg
#   inflating: Face_shape_5/Heart/heart (890).jpg
#   inflating: Face_shape_5/Heart/heart (891).jpg
#   inflating: Face_shape_5/Heart/heart (892).jpg
#   inflating: Face_shape_5/Heart/heart (893).jpg
#   inflating: Face_shape_5/Heart/heart (894).jpg
#   inflating: Face_shape_5/Heart/heart (895).jpg
#   inflating: Face_shape_5/Heart/heart (896).jpg
#   inflating: Face_shape_5/Heart/heart (897).jpg
#   inflating: Face_shape_5/Heart/heart (898).jpg
#   inflating: Face_shape_5/Heart/heart (899).jpg
#   inflating: Face_shape_5/Heart/heart (900).jpg
#   inflating: Face_shape_5/Heart/heart (901).jpg
#   inflating: Face_shape_5/Heart/heart (902).jpg
#   inflating: Face_shape_5/Heart/heart (903).jpg
#   inflating: Face_shape_5/Heart/heart (904).jpg
#   inflating: Face_shape_5/Heart/heart (905).jpg
#   inflating: Face_shape_5/Heart/heart (906).jpg
#   inflating: Face_shape_5/Heart/heart (907).jpg
#   inflating: Face_shape_5/Heart/heart (908).jpg
#   inflating: Face_shape_5/Heart/heart (909).jpg
#   inflating: Face_shape_5/Heart/heart (91).jpg
#   inflating: Face_shape_5/Heart/heart (910).jpg
#   inflating: Face_shape_5/Heart/heart (911).jpg
#   inflating: Face_shape_5/Heart/heart (912).jpg
#   inflating: Face_shape_5/Heart/heart (913).jpg
#   inflating: Face_shape_5/Heart/heart (971).jpg
#   inflating: Face_shape_5/Heart/heart (972).jpg
#   inflating: Face_shape_5/Heart/heart (973).jpg
#   inflating: Face_shape_5/Heart/heart (974).jpg
# ...
#   inflating: Face_shape_5/Square/square (696).jpg
#   inflating: Face_shape_5/Square/square (697).jpg
#   inflating: Face_shape_5/Square/square (699).jpg
#   inflating: Face_shape_5/Square/square (7).jpg
#   inflating: Face_shape_5/Square/square (700).jpg
#   inflating: Face_shape_5/Square/square (701).jpg
#   inflating: Face_shape_5/Square/square (702).jpg
#   inflating: Face_shape_5/Square/square (703).jpg
#   inflating: Face_shape_5/Square/square (704).jpg
#   inflating: Face_shape_5/Square/square (705).jpg
#   inflating: Face_shape_5/Square/square (706).jpg
#   inflating: Face_shape_5/Square/square (707).jpg
#   inflating: Face_shape_5/Square/square (708).jpg
#   inflating: Face_shape_5/Square/square (709).jpg
#   inflating: Face_shape_5/Square/square (71).jpg
#   inflating: Face_shape_5/Square/square (710).jpg
#   inflating: Face_shape_5/Square/square (711).jpg
#   inflating: Face_shape_5/Square/square (712).jpg
#   inflating: Face_shape_5/Square/square (713).jpg
#   inflating: Face_shape_5/Square/square (714).jpg
#   inflating: Face_shape_5/Square/square (715).jpg
#   inflating: Face_shape_5/Square/square (716).jpg
#   inflating: Face_shape_5/Square/square (717).jpg
#   inflating: Face_shape_5/Square/square (718).jpg
#   inflating: Face_shape_5/Square/square (719).jpg
#   inflating: Face_shape_5/Square/square (720).jpg
#   inflating: Face_shape_5/Square/square (721).jpg
#   inflating: Face_shape_5/Square/square (722).jpg
#   inflating: Face_shape_5/Square/square (723).jpg
#   inflating: Face_shape_5/Square/square (724).jpg
#   inflating: Face_shape_5/Square/square (725).jpg
#   inflating: Face_shape_5/Square/square (726).jpg
#   inflating: Face_shape_5/Square/square (727).jpg
#   inflating: Face_shape_5/Square/square (728).jpg
#   inflating: Face_shape_5/Square/square (729).jpg
#   inflating: Face_shape_5/Square/square (730).jpg
#   inflating: Face_shape_5/Square/square (731).jpg
#   inflating: Face_shape_5/Square/square (732).jpg
#   inflating: Face_shape_5/Square/square (733).jpg
#   inflating: Face_shape_5/Square/square (734).jpg
#   inflating: Face_shape_5/Square/square (735).jpg
#   inflating: Face_shape_5/Square/square (736).jpg
#   inflating: Face_shape_5/Square/square (737).jpg
#   inflating: Face_shape_5/Square/square (738).jpg
#   inflating: Face_shape_5/Square/square (739).jpg
#   inflating: Face_shape_5/Square/square (740).jpg
#   inflating: Face_shape_5/Square/square (741).jpg
#   inflating: Face_shape_5/Square/square (742).jpg
#   inflating: Face_shape_5/Square/square (743).jpg
#   inflating: Face_shape_5/Square/square (744).jpg
#   inflating: Face_shape_5/Square/square (745).jpg
#   inflating: Face_shape_5/Square/square (746).jpg
#   inflating: Face_shape_5/Square/square (747).jpg
#   inflating: Face_shape_5/Square/square (748).jpg
#   inflating: Face_shape_5/Square/square (749).jpg
#   inflating: Face_shape_5/Square/square (750).jpg
#   inflating: Face_shape_5/Square/square (751).jpg
#   inflating: Face_shape_5/Square/square (752).jpg
#   inflating: Face_shape_5/Square/square (753).jpg
#   inflating: Face_shape_5/Square/square (754).jpg
#   inflating: Face_shape_5/Square/square (755).jpg
#   inflating: Face_shape_5/Square/square (756).jpg
#   inflating: Face_shape_5/Square/square (757).jpg
#   inflating: Face_shape_5/Square/square (758).jpg
#   inflating: Face_shape_5/Square/square (759).jpg
#   inflating: Face_shape_5/Square/square (760).jpg
#   inflating: Face_shape_5/Square/square (761).jpg
#   inflating: Face_shape_5/Square/square (762).jpg
#   inflating: Face_shape_5/Square/square (763).jpg
#   inflating: Face_shape_5/Square/square (764).jpg
#   inflating: Face_shape_5/Square/square (765).jpg
#   inflating: Face_shape_5/Square/square (766).jpg
#   inflating: Face_shape_5/Square/square (767).jpg
#   inflating: Face_shape_5/Square/square (768).jpg
#   inflating: Face_shape_5/Square/square (769).jpg
#   inflating: Face_shape_5/Square/square (770).jpg
#   inflating: Face_shape_5/Square/square (771).jpg
#   inflating: Face_shape_5/Square/square (772).jpg
#   inflating: Face_shape_5/Square/square (773).jpg
#   inflating: Face_shape_5/Square/square (774).jpg
#   inflating: Face_shape_5/Square/square (775).jpg
#   inflating: Face_shape_5/Square/square (776).jpg
#   inflating: Face_shape_5/Square/square (777).jpg
#   inflating: Face_shape_5/Square/square (778).jpg
#   inflating: Face_shape_5/Square/square (779).jpg
#   inflating: Face_shape_5/Square/square (780).jpg
#   inflating: Face_shape_5/Square/square (781).jpg
#   inflating: Face_shape_5/Square/square (782).jpg
#   inflating: Face_shape_5/Square/square (783).jpg
#   inflating: Face_shape_5/Square/square (784).jpg
#   inflating: Face_shape_5/Square/square (785).jpg
#   inflating: Face_shape_5/Square/square (786).jpg
#   inflating: Face_shape_5/Square/square (787).jpg
#   inflating: Face_shape_5/Square/square (788).jpg
#   inflating: Face_shape_5/Square/square (789).jpg
#   inflating: Face_shape_5/Square/square (790).jpg
#   inflating: Face_shape_5/Square/square (791).jpg
#   inflating: Face_shape_5/Square/square (792).jpg
#   inflating: Face_shape_5/Square/square (793).jpg
#   inflating: Face_shape_5/Square/square (794).jpg
#   inflating: Face_shape_5/Square/square (795).jpg
#   inflating: Face_shape_5/Square/square (796).jpg
#   inflating: Face_shape_5/Square/square (797).jpg
#   inflating: Face_shape_5/Square/square (798).jpg
#   inflating: Face_shape_5/Square/square (799).jpg
#   inflating: Face_shape_5/Square/square (8).jpg
#   inflating: Face_shape_5/Square/square (800).jpg
#   inflating: Face_shape_5/Square/square (801).jpg
#   inflating: Face_shape_5/Square/square (802).jpg
#   inflating: Face_shape_5/Square/square (803).jpg
#   inflating: Face_shape_5/Square/square (804).jpg
#   inflating: Face_shape_5/Square/square (805).jpg
#   inflating: Face_shape_5/Square/square (806).jpg
#   inflating: Face_shape_5/Square/square (807).jpg
#   inflating: Face_shape_5/Square/square (808).jpg
#   inflating: Face_shape_5/Square/square (809).jpg
#   inflating: Face_shape_5/Square/square (810).jpg
#   inflating: Face_shape_5/Square/square (811).jpg
#   inflating: Face_shape_5/Square/square (812).jpg
#   inflating: Face_shape_5/Square/square (813).jpg
#   inflating: Face_shape_5/Square/square (814).jpg
#   inflating: Face_shape_5/Square/square (815).jpg
#   inflating: Face_shape_5/Square/square (816).jpg
#   inflating: Face_shape_5/Square/square (817).jpg
#   inflating: Face_shape_5/Square/square (818).jpg
#   inflating: Face_shape_5/Square/square (819).jpg
#   inflating: Face_shape_5/Square/square (820).jpg
#   inflating: Face_shape_5/Square/square (821).jpg
#   inflating: Face_shape_5/Square/square (822).jpg
#   inflating: Face_shape_5/Square/square (823).jpg
#   inflating: Face_shape_5/Square/square (824).jpg
#   inflating: Face_shape_5/Square/square (825).jpg
#   inflating: Face_shape_5/Square/square (826).jpg
#   inflating: Face_shape_5/Square/square (827).jpg
#   inflating: Face_shape_5/Square/square (828).jpg
#   inflating: Face_shape_5/Square/square (829).jpg
#   inflating: Face_shape_5/Square/square (830).jpg
#   inflating: Face_shape_5/Square/square (831).jpg
#   inflating: Face_shape_5/Square/square (832).jpg
#   inflating: Face_shape_5/Square/square (833).jpg
#   inflating: Face_shape_5/Square/square (834).jpg
#   inflating: Face_shape_5/Square/square (835)_tau.jpg
#   inflating: Face_shape_5/Square/square (836).jpg
#   inflating: Face_shape_5/Square/square (837).jpg
#   inflating: Face_shape_5/Square/square (838).jpg
#   inflating: Face_shape_5/Square/square (839).jpg
#   inflating: Face_shape_5/Square/square (840).jpg
#   inflating: Face_shape_5/Square/square (841).jpg
#   inflating: Face_shape_5/Square/square (842).jpg
#   inflating: Face_shape_5/Square/square (843).jpg
#   inflating: Face_shape_5/Square/square (844).jpg
#   inflating: Face_shape_5/Square/square (845).jpg
#   inflating: Face_shape_5/Square/square (846).jpg
#   inflating: Face_shape_5/Square/square (847).jpg
#   inflating: Face_shape_5/Square/square (848).jpg
#   inflating: Face_shape_5/Square/square (849).jpg
#   inflating: Face_shape_5/Square/square (850).jpg
#   inflating: Face_shape_5/Square/square (851).jpg
#   inflating: Face_shape_5/Square/square (852).jpg
#   inflating: Face_shape_5/Square/square (853).jpg
#   inflating: Face_shape_5/Square/square (854).jpg
#   inflating: Face_shape_5/Square/square (855).jpg
#   inflating: Face_shape_5/Square/square (856).jpg
#   inflating: Face_shape_5/Square/square (857).jpg
#   inflating: Face_shape_5/Square/square (858).jpg
#   inflating: Face_shape_5/Square/square (859).jpg
#   inflating: Face_shape_5/Square/square (860).jpg
#   inflating: Face_shape_5/Square/square (861).jpg
#   inflating: Face_shape_5/Square/square (862).jpg
#   inflating: Face_shape_5/Square/square (863).jpg
#   inflating: Face_shape_5/Square/square (864).jpg
#   inflating: Face_shape_5/Square/square (865).jpg
#   inflating: Face_shape_5/Square/square (866).jpg
#   inflating: Face_shape_5/Square/square (867).jpg
#   inflating: Face_shape_5/Square/square (868).jpg
#   inflating: Face_shape_5/Square/square (869).jpg
#   inflating: Face_shape_5/Square/square (870).jpg
#   inflating: Face_shape_5/Square/square (871).jpg
#   inflating: Face_shape_5/Square/square (872).jpg
#   inflating: Face_shape_5/Square/square (873).jpg
#   inflating: Face_shape_5/Square/square (874).jpg
#   inflating: Face_shape_5/Square/square (875).jpg
#   inflating: Face_shape_5/Square/square (876).jpg
#   inflating: Face_shape_5/Square/square (877).jpg
#   inflating: Face_shape_5/Square/square (878).jpg
#   inflating: Face_shape_5/Square/square (879).jpg
#   inflating: Face_shape_5/Square/square (880).jpg
#   inflating: Face_shape_5/Square/square (881).jpg
#   inflating: Face_shape_5/Square/square (882).jpg
#   inflating: Face_shape_5/Square/square (883).jpg
#   inflating: Face_shape_5/Square/square (884).jpg
#   inflating: Face_shape_5/Square/square (885).jpg
#   inflating: Face_shape_5/Square/square (886).jpg
#   inflating: Face_shape_5/Square/square (887).jpg
#   inflating: Face_shape_5/Square/square (888).jpg
#   inflating: Face_shape_5/Square/square (889).jpg
#   inflating: Face_shape_5/Square/square (890).jpg
#   inflating: Face_shape_5/Square/square (891).jpg
#   inflating: Face_shape_5/Square/square (892).jpg
#   inflating: Face_shape_5/Square/square (893).jpg
#   inflating: Face_shape_5/Square/square (894).jpg
#   inflating: Face_shape_5/Square/square (895).jpg
#   inflating: Face_shape_5/Square/square (896).jpg
#   inflating: Face_shape_5/Square/square (897).jpg
#   inflating: Face_shape_5/Square/square (898).jpg
#   inflating: Face_shape_5/Square/square (899).jpg
#   inflating: Face_shape_5/Square/square (9).jpg
#   inflating: Face_shape_5/Square/square (900).jpg
#   inflating: Face_shape_5/Square/square (901).jpg
#   inflating: Face_shape_5/Square/square (902).jpg
#   inflating: Face_shape_5/Square/square (903).jpg
#   inflating: Face_shape_5/Square/square (904).jpg
#   inflating: Face_shape_5/Square/square (905).jpg
#   inflating: Face_shape_5/Square/square (906).jpg
#   inflating: Face_shape_5/Square/square (907).jpg
#   inflating: Face_shape_5/Square/square (908).jpg
#   inflating: Face_shape_5/Square/square (909).jpg
#   inflating: Face_shape_5/Square/square (910).jpg
#   inflating: Face_shape_5/Square/square (911).jpg
#   inflating: Face_shape_5/Square/square (912).jpg
#   inflating: Face_shape_5/Square/square (913).jpg
#   inflating: Face_shape_5/Square/square (914).jpg
#   inflating: Face_shape_5/Square/square (915).jpg
#   inflating: Face_shape_5/Square/square (916).jpg
#   inflating: Face_shape_5/Square/square (917).jpg
#   inflating: Face_shape_5/Square/square (918).jpg
#   inflating: Face_shape_5/Square/square (919).jpg
#   inflating: Face_shape_5/Square/square (920).jpg
#   inflating: Face_shape_5/Square/square (921).jpg
#   inflating: Face_shape_5/Square/square (922).jpg
#   inflating: Face_shape_5/Square/square (923).jpg
#   inflating: Face_shape_5/Square/square (924).jpg
#   inflating: Face_shape_5/Square/square (925).jpg
#   inflating: Face_shape_5/Square/square (926).jpg
#   inflating: Face_shape_5/Square/square (927).jpg
#   inflating: Face_shape_5/Square/square (928).jpg
#   inflating: Face_shape_5/Square/square (929).jpg
#   inflating: Face_shape_5/Square/square (930).jpg
#   inflating: Face_shape_5/Square/square (931).jpg
#   inflating: Face_shape_5/Square/square (932).jpg
#   inflating: Face_shape_5/Square/square (933).jpg
#   inflating: Face_shape_5/Square/square (934).jpg
#   inflating: Face_shape_5/Square/square (935).jpg
#   inflating: Face_shape_5/Square/square (936).jpg
#   inflating: Face_shape_5/Square/square (937).jpg
#   inflating: Face_shape_5/Square/square (938).jpg
#   inflating: Face_shape_5/Square/square (939).jpg
#   inflating: Face_shape_5/Square/square (940).jpg
#   inflating: Face_shape_5/Square/square (941).jpg
#   inflating: Face_shape_5/Square/square (942).jpg
#   inflating: Face_shape_5/Square/square (943).jpg
#   inflating: Face_shape_5/Square/square (944).jpg
#   inflating: Face_shape_5/Square/square (945).jpg
#   inflating: Face_shape_5/Square/square (946).jpg
#   inflating: Face_shape_5/Square/square (947).jpg
#   inflating: Face_shape_5/Square/square (948).jpg
#   inflating: Face_shape_5/Square/square (949).jpg
#   inflating: Face_shape_5/Square/square (950).jpg
#   inflating: Face_shape_5/Square/square (951).jpg
#   inflating: Face_shape_5/Square/square (952).jpg
#   inflating: Face_shape_5/Square/square (953).jpg
#   inflating: Face_shape_5/Square/square (954).jpg
#   inflating: Face_shape_5/Square/square (955).jpg
#   inflating: Face_shape_5/Square/square (956).jpg
#   inflating: Face_shape_5/Square/square (957).jpg
#   inflating: Face_shape_5/Square/square (958).jpg
#   inflating: Face_shape_5/Square/square (959).jpg
#   inflating: Face_shape_5/Square/square (960).jpg
#   inflating: Face_shape_5/Square/square (961).jpg
#   inflating: Face_shape_5/Square/square (962).jpg
#   inflating: Face_shape_5/Square/square (963).jpg
#   inflating: Face_shape_5/Square/square (964).jpg
#   inflating: Face_shape_5/Square/square (965).jpg
#   inflating: Face_shape_5/Square/square (966).jpg
#   inflating: Face_shape_5/Square/square (967).jpg
#   inflating: Face_shape_5/Square/square (968).jpg
#   inflating: Face_shape_5/Square/square (969).jpg
#   inflating: Face_shape_5/Square/square (970).jpg
#   inflating: Face_shape_5/Square/square (971).jpg
#   inflating: Face_shape_5/Square/square (972).jpg
#   inflating: Face_shape_5/Square/square (973).jpg
#   inflating: Face_shape_5/Square/square (974).jpg
#   inflating: Face_shape_5/Square/square (975).jpg
#   inflating: Face_shape_5/Square/square (976).jpg
#   inflating: Face_shape_5/Square/square (977).jpg
#   inflating: Face_shape_5/Square/square (978).jpg
#   inflating: Face_shape_5/Square/square (979).jpg
#   inflating: Face_shape_5/Square/square (980).jpg
#   inflating: Face_shape_5/Square/square (981).jpg
#   inflating: Face_shape_5/Square/square (982).jpg
#   inflating: Face_shape_5/Square/square (983).jpg
#   inflating: Face_shape_5/Square/square (984).jpg
#   inflating: Face_shape_5/Square/square (985).jpg
#   inflating: Face_shape_5/Square/square (986).jpg
#   inflating: Face_shape_5/Square/square (987).jpg
#   inflating: Face_shape_5/Square/square (988).jpg
#   inflating: Face_shape_5/Square/square (989).jpg
#   inflating: Face_shape_5/Square/square (990).jpg
#   inflating: Face_shape_5/Square/square (991).jpg
#   inflating: Face_shape_5/Square/square (992).jpg
#   inflating: Face_shape_5/Square/square (993).jpg
#   inflating: Face_shape_5/Square/square (994).jpg
#   inflating: Face_shape_5/Square/square (995).jpg
#   inflating: Face_shape_5/Square/square (996).jpg
#   inflating: Face_shape_5/Square/square (997).jpg
#   inflating: Face_shape_5/Square/square (998).jpg
#   inflating: Face_shape_5/Square/square (999).jpg

# %%
import numpy as np # linear algebra
import pandas as pd  # data processing
import os #  to interact with files using there paths
from sklearn.datasets import load_files

# %%
#The path of our data on drive
data_dir =  '/content/Face_shape_5'

# %%
#Loading our Data
data = load_files(data_dir)

# %%
folders=os.listdir('/content/Face_shape_5')
print(folders)
# Out:
# ['Oval', 'Oblong', 'Round', 'Square', 'Heart']

# %%
X = np.array(data['filenames'])
y = np.array(data['target'])
labels = np.array(data['target_names'])
 
# How the arrays look like?
print('Data files - ',X)
print('Target labels - ',y)
# Out:
# Data files -  ['/content/Face_shape_5/Round/round (395).jpg'
#  '/content/Face_shape_5/Oblong/47_Oblong.jpg'
#  '/content/Face_shape_5/Square/square (529).jpg' ...
#  '/content/Face_shape_5/Oblong/oblong (564).jpg'
#  '/content/Face_shape_5/Oval/oval (641).jpg'
#  '/content/Face_shape_5/Oval/oval (757).jpg']
# Target labels -  [3 1 4 ... 1 2 2]

# %%
# Remove .pyc or .py files
pyc_file_pos = (np.where(file==X) for file in X if file.endswith(('.pyc','.py')))
for pos in pyc_file_pos:
    X = np.delete(X,pos)
    y = np.delete(y,pos)
    
print('Number of training files : ', X.shape[0])
print('Number of training targets : ', y.shape[0])
# Out:
# Number of training files :  4900
# Number of training targets :  4900

# %%
from keras.preprocessing.image import img_to_array, load_img

def convert_img_to_arr(file_path_list):
    arr = []
    #size=64,64
    img_width, img_height = 224,224
    for file_path in file_path_list:
        img = load_img(file_path, target_size = (img_width, img_height))
        img = img_to_array(img)
        arr.append(img)
        #arr.append(cv2.resize(img,size))
    return arr
 
X = np.array(convert_img_to_arr(X))
print(X.shape) 
print('First training item : ',X[0])
# Out:
# (4900, 224, 224, 3)
# First training item :  [[[ 71. 226. 254.]
#   [ 71. 226. 254.]
#   [ 71. 226. 254.]
#   ...
#   [ 69. 222. 253.]
#   [ 69. 222. 253.]
#   [ 70. 223. 254.]]
#
#  [[ 71. 225. 253.]
#   [ 72. 226. 254.]
#   [ 72. 226. 254.]
#   ...
#   [ 69. 222. 253.]
#   [ 69. 222. 253.]
#   [ 70. 223. 254.]]
#
#  [[ 73. 224. 253.]
#   [ 73. 224. 253.]
#   [ 73. 224. 253.]
#   ...
#   [ 70. 223. 254.]
#   [ 69. 222. 253.]
#   [ 70. 223. 254.]]
#
#  ...
#
#  [[ 46. 182. 220.]
#   [ 40. 180. 216.]
#   [ 43. 183. 219.]
#   ...
#   [ 31.  65. 162.]
#   [ 33.  66. 163.]
#   [ 33.  66. 163.]]
#
#  [[ 46. 180. 218.]
#   [ 41. 179. 216.]
#   [ 44. 182. 221.]
#   ...
#   [ 36.  66. 162.]
#   [ 38.  66. 165.]
#   [ 38.  66. 165.]]
#
#  [[ 49. 180. 222.]
#   [ 45. 181. 221.]
#   [ 46. 184. 223.]
#   ...
#   [ 40.  66. 163.]
#   [ 42.  67. 167.]
#   [ 43.  67. 167.]]]

# %%
#Let's look at first 5 training data.

import matplotlib.pyplot as plt
 
fig = plt.figure(figsize = (16,9))
for i in range(5):
    ax = fig.add_subplot(1,5,i+1,xticks=[],yticks=[])
    ax.imshow((X[i].astype(np.uint8)))
    plt.title(folders[y[i]])

# %%
# Let's resize or rescale training data
X = X.astype('float32')/255
 
# Let's confirm the number of classes :) 
no_of_classes = len(np.unique(y))
no_of_classes
# Out:
# 5

# %%
y
# Out:
# array([3, 1, 4, ..., 1, 2, 2])

# %%
from keras.utils import np_utils

# let's converts a class vector (integers) to binary class matrix.
y = np.array(np_utils.to_categorical(y,no_of_classes))
y[0]
# Out:
# array([0., 0., 0., 1., 0.], dtype=float32)

# %%
from sklearn.model_selection import train_test_split

# let's splite the data into subsets and explore their shapes !

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
print('The test Data Shape ', X_test.shape[0])
 
X_test, X_valid, y_test, y_valid = train_test_split(X_test,y_test, test_size = 0.5)
print('The training Data Shape ', X_valid.shape[0])
# Out:
# The test Data Shape  980
# The training Data Shape  490

# %%
print('The train Data Shape ', X_train.shape[1:])
# Out:
# The train Data Shape  (224, 224, 3)

# %%
from tensorflow.keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
import tensorflow.keras.backend as K

class Mish(Activation):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X = Activation('Mish', name="conv1_act")(X_input)
    '''

    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'Mish'


def mish(x):
    return x*K.tanh(K.softplus(x))

get_custom_objects().update({'Mish': Mish(mish)})

# %%
from keras.models import Model
from keras.layers import Input
from keras.applications import InceptionResNetV2
from keras.preprocessing import image
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD, Adam, Nadam
from keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, ZeroPadding2D, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

img_width, img_height = 224,224


input_tensor = Input(shape=(img_width, img_height,3))

base_model = InceptionResNetV2(weights='imagenet',
                                            include_top=False,
                                            input_shape=(img_width, img_height, 3),
                                            pooling='avg')


top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dropout(0.5)) 

top_model.add(Dense(5, activation='softmax'))

model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 111, 111, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 109, 109, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 109, 109, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 109, 109, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 54, 54, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 54, 54, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 54, 54, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 52, 52, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 52, 52, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 52, 52, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 25, 25, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 96)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   12288       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 25, 25, 96)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 25, 25, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 25, 25, 320)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 48)   13824       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 48)   144         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 64)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 25, 25, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 25, 25, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 48)   13824       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 48)   144         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 48)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   27648       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 25, 25, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 25, 25, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 25, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 25, 25, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 25, 25, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 48)   13824       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 48)   144         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 48)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 32)   9216        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 64)   27648       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 64)   192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 25, 25, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 25, 25, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 25, 25, 48)   13824       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 48)   144         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 48)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 25, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 25, 25, 64)   27648       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 25, 25, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 25, 25, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 25, 25, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 25, 25, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 25, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 25, 25, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 25, 25, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 25, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 25, 25, 48)   13824       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 25, 25, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 25, 25, 48)   144         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 25, 25, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 25, 25, 48)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 25, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 25, 25, 32)   9216        activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 25, 25, 64)   27648       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 25, 25, 32)   96          conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 25, 25, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 25, 25, 64)   192         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 25, 25, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 25, 25, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 25, 25, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 25, 25, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 25, 25, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 25, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 25, 25, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 25, 25, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 25, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 25, 25, 48)   13824       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 25, 25, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 25, 25, 48)   144         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 25, 25, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 25, 25, 48)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 25, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 25, 25, 32)   9216        activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 25, 25, 64)   27648       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 25, 25, 32)   96          conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 25, 25, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 25, 25, 64)   192         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 25, 25, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 25, 25, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 25, 25, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 25, 25, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 25, 25, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 25, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 25, 25, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 25, 25, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 25, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 25, 25, 48)   13824       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 25, 25, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 25, 25, 48)   144         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 25, 25, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 25, 25, 48)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 25, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 25, 25, 32)   9216        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 25, 25, 64)   27648       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 25, 25, 32)   96          conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 25, 25, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 25, 25, 64)   192         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 25, 25, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 25, 25, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 25, 25, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 25, 25, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 25, 25, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 25, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 25, 25, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 25, 25, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 25, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 25, 25, 48)   13824       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 25, 25, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 25, 25, 48)   144         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 25, 25, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 25, 25, 48)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 25, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 25, 25, 32)   9216        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 25, 25, 64)   27648       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 25, 25, 32)   96          conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 25, 25, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 25, 25, 64)   192         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 25, 25, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 25, 25, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 25, 25, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 25, 25, 128)  0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 25, 25, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 25, 25, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 25, 25, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 25, 25, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 25, 25, 32)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 25, 25, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 25, 25, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 25, 25, 48)   13824       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 25, 25, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 25, 25, 48)   144         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 25, 25, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 25, 25, 48)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 25, 25, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 5, 5, 192)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 5, 5, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 5, 5, 448)    0           activation_183[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 5, 5, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 5, 5, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 5, 5, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 5, 5, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 5, 5, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 5, 5, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 5, 5, 224)    129024      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 5, 5, 224)    672         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 5, 5, 224)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 5, 5, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 5, 5, 256)    172032      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 5, 5, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 5, 5, 256)    768         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 5, 5, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 5, 5, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 5, 5, 448)    0           activation_187[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 5, 5, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 5, 5, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 5, 5, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 5, 5, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 5, 5, 192)    576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 5, 5, 192)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 5, 5, 224)    129024      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 5, 5, 224)    672         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 5, 5, 224)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 5, 5, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 5, 5, 256)    172032      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 5, 5, 192)    576         conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 5, 5, 256)    768         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 5, 5, 192)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 5, 5, 256)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 5, 5, 448)    0           activation_191[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 5, 5, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 5, 5, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 5, 5, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 5, 5, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 5, 5, 192)    576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 5, 5, 192)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 5, 5, 224)    129024      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 5, 5, 224)    672         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 5, 5, 224)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 5, 5, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 5, 5, 256)    172032      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 5, 5, 192)    576         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 5, 5, 256)    768         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 5, 5, 192)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 5, 5, 256)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 5, 5, 448)    0           activation_195[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 5, 5, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 5, 5, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 5, 5, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 5, 5, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 5, 5, 192)    576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 5, 5, 192)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 5, 5, 224)    129024      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 5, 5, 224)    672         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 5, 5, 224)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 5, 5, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 5, 5, 256)    172032      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 5, 5, 192)    576         conv2d_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 5, 5, 256)    768         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 5, 5, 192)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 5, 5, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 5, 5, 448)    0           activation_199[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 5, 5, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 5, 5, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 5, 5, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 5, 5, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 5, 5, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 5)            7685        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 54,344,421
# Trainable params: 54,283,877
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
optimizer=Nadam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau
 
# Time to train our model !
epochs = 25
batch_size=32
 
train_datagen = ImageDataGenerator(
        rotation_range=10,  
        zoom_range = 0.1, 
        width_shift_range=0.1,
        height_shift_range=0.1,  
        horizontal_flip=True)
 
test_datagen = ImageDataGenerator()
 
train_generator = train_datagen.flow(
    X_train,y_train,
    batch_size=batch_size)
 
validation_generator = test_datagen.flow(
    X_valid,y_valid,
    batch_size=batch_size)
 
#checkpointer = ModelCheckpoint(filepath ="/content/sample_data/Inception_ResNet_v2.h5", save_best_only = True, verbose = 1)
#learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose = 1, factor = 0.5, minlr = 0.00001)


checkpointer = ModelCheckpoint(filepath ="/content/sample_data/Inception_ResNet_v2.h5", save_best_only = True, save_weights_only=True, verbose = 1)
tensorBoard = TensorBoard(log_dir="/content/sample_data/Inception_ResNet_v2", write_graph=True, write_images=True)
learning_rate_reduction = ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)
earlystopping_rate = EarlyStopping(patience=30, verbose=1)

start = time.time()


history=model.fit_generator(train_generator,
                            epochs=epochs,
                            validation_data = validation_generator,
                            verbose=1,
                            steps_per_epoch=len(X_train) // batch_size,
                            callbacks=[checkpointer, tensorBoard, learning_rate_reduction])
 
end = time.time()
 
duration = end - start
print ('\n This Model took %0.2f seconds (%0.1f minutes) to train for %d epochs'%(duration, duration/60, epochs) )
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 122/122 [==============================] - 162s 716ms/step - loss: 1.4845 - accuracy: 0.3523 - val_loss: 1.1112 - val_accuracy: 0.6122
#
# Epoch 00001: val_loss improved from inf to 1.11124, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 2/25
# 122/122 [==============================] - 80s 652ms/step - loss: 0.7110 - accuracy: 0.7281 - val_loss: 0.8457 - val_accuracy: 0.7163
#
# Epoch 00002: val_loss improved from 1.11124 to 0.84574, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 3/25
# 122/122 [==============================] - 81s 659ms/step - loss: 0.4168 - accuracy: 0.8342 - val_loss: 0.7051 - val_accuracy: 0.7592
#
# Epoch 00003: val_loss improved from 0.84574 to 0.70507, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 4/25
# 122/122 [==============================] - 81s 665ms/step - loss: 0.2737 - accuracy: 0.9022 - val_loss: 0.7003 - val_accuracy: 0.7612
#
# Epoch 00004: val_loss improved from 0.70507 to 0.70034, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 5/25
# 122/122 [==============================] - 82s 668ms/step - loss: 0.1820 - accuracy: 0.9357 - val_loss: 0.5660 - val_accuracy: 0.8367
#
# Epoch 00005: val_loss improved from 0.70034 to 0.56604, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 6/25
# 122/122 [==============================] - 82s 667ms/step - loss: 0.1666 - accuracy: 0.9399 - val_loss: 0.6940 - val_accuracy: 0.7918
#
# Epoch 00006: val_loss did not improve from 0.56604
# Epoch 7/25
# 122/122 [==============================] - 82s 670ms/step - loss: 0.1323 - accuracy: 0.9559 - val_loss: 0.8193 - val_accuracy: 0.7796
#
# Epoch 00007: val_loss did not improve from 0.56604
# Epoch 8/25
# 122/122 [==============================] - 82s 670ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.9174 - val_accuracy: 0.7694
#
# Epoch 00008: val_loss did not improve from 0.56604
# Epoch 9/25
# 122/122 [==============================] - 82s 670ms/step - loss: 0.1097 - accuracy: 0.9613 - val_loss: 0.7768 - val_accuracy: 0.7898
#
# Epoch 00009: val_loss did not improve from 0.56604
# Epoch 10/25
# 122/122 [==============================] - 82s 671ms/step - loss: 0.0791 - accuracy: 0.9758 - val_loss: 0.5989 - val_accuracy: 0.8347
#
# Epoch 00010: val_loss did not improve from 0.56604
# Epoch 11/25
# 122/122 [==============================] - 82s 670ms/step - loss: 0.0611 - accuracy: 0.9797 - val_loss: 0.5785 - val_accuracy: 0.8531
#
# Epoch 00011: val_loss did not improve from 0.56604
# Epoch 12/25
# 122/122 [==============================] - 82s 670ms/step - loss: 0.0632 - accuracy: 0.9798 - val_loss: 0.5720 - val_accuracy: 0.8571
#
# Epoch 00012: val_loss did not improve from 0.56604
# Epoch 13/25
# 122/122 [==============================] - 82s 671ms/step - loss: 0.0607 - accuracy: 0.9811 - val_loss: 0.6521 - val_accuracy: 0.8327
#
# Epoch 00013: val_loss did not improve from 0.56604
# Epoch 14/25
# 122/122 [==============================] - 82s 674ms/step - loss: 0.0522 - accuracy: 0.9821 - val_loss: 0.9280 - val_accuracy: 0.7735
#
# Epoch 00014: val_loss did not improve from 0.56604
# Epoch 15/25
# 122/122 [==============================] - 82s 674ms/step - loss: 0.0752 - accuracy: 0.9739 - val_loss: 0.5457 - val_accuracy: 0.8347
#
# Epoch 00015: val_loss improved from 0.56604 to 0.54569, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 16/25
# 122/122 [==============================] - 83s 675ms/step - loss: 0.0477 - accuracy: 0.9850 - val_loss: 0.6643 - val_accuracy: 0.8163
#
# Epoch 00016: val_loss did not improve from 0.54569
# Epoch 17/25
# 122/122 [==============================] - 83s 677ms/step - loss: 0.0473 - accuracy: 0.9839 - val_loss: 9.7858 - val_accuracy: 0.1837
#
# Epoch 00017: val_loss did not improve from 0.54569
# Epoch 18/25
# 122/122 [==============================] - 83s 677ms/step - loss: 0.0486 - accuracy: 0.9840 - val_loss: 0.5358 - val_accuracy: 0.8469
#
# Epoch 00018: val_loss improved from 0.54569 to 0.53585, saving model to /content/sample_data/Inception_ResNet_v2.h5
# Epoch 19/25
# 122/122 [==============================] - 83s 675ms/step - loss: 0.0470 - accuracy: 0.9811 - val_loss: 0.5466 - val_accuracy: 0.8429
#
# Epoch 00019: val_loss did not improve from 0.53585
# Epoch 20/25
# 122/122 [==============================] - 83s 676ms/step - loss: 0.0271 - accuracy: 0.9917 - val_loss: 0.6896 - val_accuracy: 0.8082
#
# Epoch 00020: val_loss did not improve from 0.53585
# Epoch 21/25
# 122/122 [==============================] - 83s 676ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 0.7508 - val_accuracy: 0.8245
#
# Epoch 00021: val_loss did not improve from 0.53585
# Epoch 22/25
# 122/122 [==============================] - 83s 676ms/step - loss: 0.0459 - accuracy: 0.9835 - val_loss: 0.7126 - val_accuracy: 0.8184
#
# Epoch 00022: val_loss did not improve from 0.53585
# Epoch 23/25
# 122/122 [==============================] - 83s 675ms/step - loss: 0.0563 - accuracy: 0.9819 - val_loss: 0.7365 - val_accuracy: 0.8184
#
# Epoch 00023: val_loss did not improve from 0.53585
# Epoch 24/25
# 122/122 [==============================] - 82s 674ms/step - loss: 0.0401 - accuracy: 0.9864 - val_loss: 0.5409 - val_accuracy: 0.8531
#
# Epoch 00024: val_loss did not improve from 0.53585
# Epoch 25/25
# 122/122 [==============================] - 83s 676ms/step - loss: 0.0508 - accuracy: 0.9829 - val_loss: 0.5743 - val_accuracy: 0.8551
#
# Epoch 00025: val_loss did not improve from 0.53585
#
#  This Model took 2143.08 seconds (35.7 minutes) to train for 25 epochs

# %%
(eval_loss, eval_accuracy) = model.evaluate(  
     X_test, y_test, batch_size=batch_size, verbose=2)
 
print("Accuracy: {:.2f}%".format(eval_accuracy * 100))  
print("Loss: {}".format(eval_loss))
# Out:
# 16/16 - 6s - loss: 0.6679 - accuracy: 0.8633
# Accuracy: 86.33%
# Loss: 0.6678791642189026

# %%
(eval_loss, eval_accuracy) = model.evaluate(  
     X_train, y_train, batch_size=batch_size, verbose=2)

print(eval_accuracy)
print("Loss: {}".format(eval_loss))
# Out:
# 123/123 - 23s - loss: 0.0193 - accuracy: 0.9934
# 0.9933673739433289
# Loss: 0.01925826631486416

# %%
(eval_loss, eval_accuracy) = model.evaluate(  
     X_valid, y_valid, batch_size=batch_size, verbose=3)

print(eval_accuracy)
print("Loss: {}".format(eval_loss))
# Out:
# 0.8551020622253418
# Loss: 0.574278712272644

# %%
# Let's visualize the train/validation loss and accuracy wrt epochs

import matplotlib.pyplot as plt 
def plot(history):
    plt.figure(2)
    #plt.figure(figsize=(10,10)) 
 
     # summarize history for accuracy  
 
    plt.subplot(211)  
    plt.plot(history.history['accuracy'])  
    plt.plot(history.history['val_accuracy'])  
    plt.title('accuracy vs val_accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='lower right')  
 
     # summarize history for loss  
 
    plt.subplot(212)  
    plt.plot(history.history['loss'])  
    plt.plot(history.history['val_loss'])  
    plt.title('loss vs val_loss')  
    plt.ylabel('loss')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.tight_layout()
    plt.show()
 
# Finaly, let's call the plot function with the 'result' parameter 
 
plot(history)

# %%
# Let's visualize some random test prediction.
def visualize_pred(y_pred):
# plot a random sample of test images, their predicted labels, and ground truth
    fig = plt.figure(figsize=(16, 9))
    for i, idx in enumerate(np.random.choice(X_test.shape[0], size=16, replace=False)):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(X_test[idx]))
        pred_idx = np.argmax(y_pred[idx])
        true_idx = np.argmax(y_test[idx])
        ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                     color=("green" if pred_idx == true_idx else "red"))

visualize_pred(model.predict(X_test))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Greens",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

# %%
target_names = ['Heart', 'Oblong', 'Oval', 'Round', 'Square', ]
print(classification_report(Y_true,Y_pred_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        Heart       0.90      0.80      0.85        96
#       Oblong       0.91      0.94      0.93       102
#         Oval       0.77      0.84      0.81        94
#        Round       0.88      0.76      0.82        88
#       Square       0.86      0.95      0.90       110
#
#     accuracy                           0.86       490
#    macro avg       0.87      0.86      0.86       490
# weighted avg       0.87      0.86      0.86       490

# %%
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle

n_classes = 5

from sklearn.metrics import roc_curve, auc

# Plot linewidth.
lw = 0.5

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], Y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), Y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle='solid', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle='solid', linewidth=4)

colors = cycle(['purple', 'cyan', 'pink', 'blue', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(5)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle='solid', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle='solid', linewidth=2)

colors = cycle(['purple', 'cyan', 'pink', 'blue', 'orange'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
